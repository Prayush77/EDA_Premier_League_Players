# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\prayu\OneDrive\Desktop\Eda_football\EDA_Premier_League_Players\data\Football.csv')

# %%
df.shape
# Out:
# (571, 59)

# %%
df.head(10)
# Out:
#                    Name  Jersey Number     Club    Position Nationality   Age  \
# 0            Bernd Leno            1.0  Arsenal  Goalkeeper     Germany  28.0
# 1            Matt Macey           33.0  Arsenal  Goalkeeper     England  26.0
# 2  Rúnar Alex Rúnarsson           13.0  Arsenal  Goalkeeper     Iceland  25.0
# 3       Héctor Bellerín            2.0  Arsenal    Defender       Spain  25.0
# 4        Kieran Tierney            3.0  Arsenal    Defender    Scotland  23.0
# 5        William Saliba            4.0  Arsenal    Defender      France  19.0
# 6              Sokratis            5.0  Arsenal    Defender      Greece  32.0
# 7           Rob Holding           16.0  Arsenal    Defender     England  25.0
# 8      Shkodran Mustafi           20.0  Arsenal    Defender     Germany  28.0
# 9        Calum Chambers           21.0  Arsenal    Defender     England  25.0
#
#    Appearances  Wins  Losses  Goals  ...  Punches  High Claims  Catches  \
# ...

# %%
df

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Throw outs                502
# Sweeper clearances        502
# Catches                   502
# High Claims               502
# Punches                   502
# Penalties saved           502
# Saves                     502
# Goal Kicks                502
# Last man tackles          378
# Clearances off line       378
# Goals conceded            309
# Own goals                 309
# Clean sheets              309
# Freekicks scored          262
# Shots                     262
# Penalties scored          262
# Goals per match           262
# Shots on target           262
# Shooting accuracy %       262
# Big chances missed        262
# Aerial battles won        181
# Recoveries                181
# Successful 50/50s         181
# Duels lost                181
# Duels won                 181
# Aerial battles lost       181
# Tackle success %          181
# Cross accuracy %          181
# Through balls             181
# Accurate long balls       112
# Errors leading to goal    112
# ...

# %%
df[df['Goals conceded'].notnull()][['Goals conceded','Name','Position','Appearances']]
# Out:
#      Goals conceded                  Name    Position  Appearances
# 0              82.0            Bernd Leno  Goalkeeper           64
# 1               0.0            Matt Macey  Goalkeeper            0
# 2               0.0  Rúnar Alex Rúnarsson  Goalkeeper            0
# 3             166.0       Héctor Bellerín    Defender          160
# 4              16.0        Kieran Tierney    Defender           16
# ..              ...                   ...         ...          ...
# 554            18.0         Rúben Vinagre    Defender           34
# 555             2.0     Maximilian Kilman    Defender            4
# 556             0.0            Oskar Buur    Defender            1
# 557             0.0                Marçal    Defender            2
# 558             0.0        Ki-Jana Hoever    Defender            0
#
# [262 rows x 4 columns]

# %%
df[df['Last man tackles'].isnull()][['Last man tackles','Name','Position','Appearances']]
# Out:
#      Last man tackles                  Name    Position  Appearances
# 0                 NaN            Bernd Leno  Goalkeeper           64
# 1                 NaN            Matt Macey  Goalkeeper            0
# 2                 NaN  Rúnar Alex Rúnarsson  Goalkeeper            0
# 13                NaN            Mesut Özil  Midfielder          184
# 14                NaN        Lucas Torreira  Midfielder           63
# ..                ...                   ...         ...          ...
# 566               NaN            Pedro Neto     Forward           31
# 567               NaN          Raúl Jiménez     Forward           78
# 568               NaN          Adama Traoré     Forward          105
# 569               NaN           Fábio Silva     Forward            1
# 570               NaN      Leonardo Campana     Forward            0
#
# [378 rows x 4 columns]

# %%
df[(df['Last man tackles'].notnull())&(df['Position']=='Defender')][['Last man tackles','Name','Position','Appearances']]
# Out:
#      Last man tackles               Name  Position  Appearances
# 3                 1.0    Héctor Bellerín  Defender          160
# 4                 0.0     Kieran Tierney  Defender           16
# 5                 0.0     William Saliba  Defender            0
# 6                 1.0           Sokratis  Defender           44
# 7                 1.0        Rob Holding  Defender           41
# ..                ...                ...       ...          ...
# 554               0.0      Rúben Vinagre  Defender           34
# 555               0.0  Maximilian Kilman  Defender            4
# 556               0.0         Oskar Buur  Defender            1
# 557               0.0             Marçal  Defender            2
# 558               0.0     Ki-Jana Hoever  Defender            0
#
# [191 rows x 4 columns]

# %%
df[df['Saves'].notnull()][['Saves','Name','Position']]
# Out:
#      Saves                  Name    Position
# 0    222.0            Bernd Leno  Goalkeeper
# 1      0.0            Matt Macey  Goalkeeper
# 2      0.0  Rúnar Alex Rúnarsson  Goalkeeper
# 30   408.0            Tom Heaton  Goalkeeper
# 31     2.0             Jed Steer  Goalkeeper
# ..     ...                   ...         ...
# 521   15.0          David Martin  Goalkeeper
# 522   85.0       Darren Randolph  Goalkeeper
# 523    0.0          Nathan Trott  Goalkeeper
# 549  195.0          Rui Patrício  Goalkeeper
# 550  389.0            John Ruddy  Goalkeeper
#
# [69 rows x 3 columns]

# %%
df.dtypes
# Out:
# Name                       object
# Jersey Number             float64
# Club                       object
# Position                   object
# Nationality                object
# Age                       float64
# Appearances                 int64
# Wins                        int64
# Losses                      int64
# Goals                       int64
# Goals per match           float64
# Headed goals              float64
# Goals with right foot     float64
# Goals with left foot      float64
# Penalties scored          float64
# Freekicks scored          float64
# Shots                     float64
# Shots on target           float64
# Shooting accuracy %        object
# Hit woodwork              float64
# Big chances missed        float64
# Clean sheets              float64
# Goals conceded            float64
# Tackles                   float64
# Tackle success %           object
# Last man tackles          float64
# Blocked shots             float64
# ...

# %%
df.columns.tolist()
# Out:
# ['Name',
#  'Jersey Number',
#  'Club',
#  'Position',
#  'Nationality',
#  'Age',
#  'Appearances',
#  'Wins',
#  'Losses',
#  'Goals',
#  'Goals per match',
#  'Headed goals',
#  'Goals with right foot',
#  'Goals with left foot',
#  'Penalties scored',
#  'Freekicks scored',
#  'Shots',
#  'Shots on target',
#  'Shooting accuracy %',
#  'Hit woodwork',
#  'Big chances missed',
#  'Clean sheets',
#  'Goals conceded',
#  'Tackles',
#  'Tackle success %',
#  'Last man tackles',
#  'Blocked shots',
#  'Interceptions',
#  'Clearances',
#  'Headed Clearance',
#  'Clearances off line',
#  'Recoveries',
#  'Duels won',
#  'Duels lost',
#  'Successful 50/50s',
#  'Aerial battles won',
#  'Aerial battles lost',
#  'Own goals',
#  'Errors leading to goal',
#  'Assists',
#  'Passes',
#  'Passes per match',
#  'Big chances created',
#  'Crosses',
#  'Cross accuracy %',
#  'Through balls',
#  'Accurate long balls',
#  'Saves',
#  'Penalties saved',
#  'Punches',
#  'High Claims',
#  'Catches',
# ...

# %%
df['Position'].value_counts()
# Out:
# Position
# Midfielder    198
# Defender      194
# Forward       110
# Goalkeeper     69
# Name: count, dtype: int64

# %%
mid_df=df[df['Position']=='Midfielder']
mid_df.shape
# Out:
# (198, 59)

# %%
mid_talent=mid_df[['Name','Club','Passes per match','Assists','Big chances created']]
mid_talent
# Out:
#                        Name                     Club  Passes per match  \
# 13               Mesut Özil                  Arsenal             60.79
# 14           Lucas Torreira                  Arsenal             39.57
# 15   Ainsley Maitland-Niles                  Arsenal             34.57
# 16           Mohamed Elneny                  Arsenal             53.87
# 17           Joseph Willock                  Arsenal             12.06
# ..                      ...                      ...               ...
# 561            Romain Saïss  Wolverhampton-Wanderers             45.43
# 562           João Moutinho  Wolverhampton-Wanderers             48.44
# 563      Leander Dendoncker  Wolverhampton-Wanderers             33.32
# 564                 Vitinha  Wolverhampton-Wanderers              5.00
# 565         Meritan Shabani  Wolverhampton-Wanderers              0.00
#
#      Assists  Big chances created
# 13        54                 65.0
# 14         3                  3.0
# ...

# %%
df['Position'].value_counts()
# Out:
# Position
# Midfielder    198
# Defender      194
# Forward       110
# Goalkeeper     69
# Name: count, dtype: int64

# %%
df[df['Age']<20]
# Out:
#                    Name  Jersey Number                      Club    Position  \
# 5        William Saliba            4.0                   Arsenal    Defender
# 21          Bukayo Saka            7.0                   Arsenal  Midfielder
# 28   Gabriel Martinelli           35.0                   Arsenal     Forward
# 53         Jacob Ramsey           41.0               Aston-Villa  Midfielder
# 63        Tariq Lamptey            2.0  Brighton-and-Hove-Albion    Defender
# 71       Haydon Roberts           58.0  Brighton-and-Hove-Albion    Defender
# 82      Lars Dendoncker           53.0  Brighton-and-Hove-Albion  Midfielder
# 102        Bobby Thomas           37.0                   Burnley    Defender
# 136       Billy Gilmour           23.0                   Chelsea  Midfielder
# 141  Callum Hudson-Odoi           20.0                   Chelsea     Forward
# 145     Nathan Ferguson            NaN            Crystal-Palace    Defender
# ...

# %%
df['league'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\prayu\anaconda3\envs\spark_env\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'league'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ...

# %%
df['Shooting accuracy %']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 566    32%
# 567    35%
# 568    27%
# 569     0%
# 570     0%
# Name: Shooting accuracy %, Length: 571, dtype: object

# %%
df.describe()
# Out:
#        Jersey Number         Age  Appearances        Wins      Losses  \
# count     563.000000  570.000000   571.000000  571.000000  571.000000
# mean       19.534636   25.789474    68.823117   28.957968   23.896673
# std        14.273515    4.377354    81.797516   38.969376   28.488376
# min         1.000000   17.000000     0.000000    0.000000    0.000000
# 25%         8.000000   22.000000     3.000000    1.000000    1.000000
# 50%        18.000000   26.000000    36.000000   12.000000   14.000000
# 75%        27.000000   29.000000   108.000000   41.000000   36.000000
# max        82.000000   38.000000   539.000000  272.000000  158.000000
#
#             Goals  Goals per match  Headed goals  Goals with right foot  \
# count  571.000000       309.000000    502.000000             502.000000
# mean     7.327496         2.648414      1.414343               4.468127
# std     16.810490         8.002117      3.433374              11.048341
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 59 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    571 non-null    object
#  1   Jersey Number           563 non-null    float64
#  2   Club                    571 non-null    object
#  3   Position                571 non-null    object
#  4   Nationality             570 non-null    object
#  5   Age                     570 non-null    float64
#  6   Appearances             571 non-null    int64
#  7   Wins                    571 non-null    int64
#  8   Losses                  571 non-null    int64
#  9   Goals                   571 non-null    int64
#  10  Goals per match         309 non-null    float64
#  11  Headed goals            502 non-null    float64
#  12  Goals with right foot   502 non-null    float64
#  13  Goals with left foot    502 non-null    float64
# ...
